# %% [markdown]
# <a href="https://colab.research.google.com/github/Propa-Punam/Wifi-RSS-Crowdsensing/blob/main/understand/part_1_understanding_phase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from io import StringIO

# Training data (3 samples for 203, 3 for 204)
train_data_str = """StudentID,room,CSE-306,CSE-304,CSE-401,CSE-104
2005037,203,-100,-71,-100,-83
2005026,203,-94,-58,-87,-80
2005006,203,-100,-68,-100,-74
2005074,204,-100,-61,-100,-82
2005084,204,-94,-58,-87,-80
2005085,204,-100,-68,-100,-74"""

# Test data (3 samples for 203, 3 for 204)
test_data_str = """StudentID,room,CSE-306,CSE-304,CSE-401,CSE-104
2005004,203,-100,-52,-100,-79
2005014,203,-77,-60,-87,-64
2005045,203,-72,-67,-77,-70
2005038,204,-72,-67,-77,-70
2005108,204,-88,-54,-82,-73
2005102,204,-72,-60,-81,-63"""

# Load data
print("Loading training data:")
train_df = pd.read_csv(StringIO(train_data_str))
print("Training DataFrame:")
print(train_df)

print("\nLoading test data:")
test_df = pd.read_csv(StringIO(test_data_str))
print("Test DataFrame:")
print(test_df)

# Extract RSSI values and zones
print("\nExtracting training features (X_train) and labels (y_train):")
X_train = train_df.iloc[:, 2:].values
y_train = train_df['room'].astype(str).values  # Convert to strings
print("X_train (RSSI values):")
print(X_train)
print("y_train (room labels):")
print(y_train)

print("\nExtracting test features (X_test) and labels (y_test):")
X_test = test_df.iloc[:, 2:].values
y_test = test_df['room'].astype(str).values  # Convert to strings
print("X_test (RSSI values):")
print(X_test)
print("y_test (room labels):")
print(y_test)

# Define zones and indices
zones = ['203', '204']
print("\nDefined zones:")
print(zones)

zone_to_idx = {zone: i for i, zone in enumerate(zones)}
print("Zone to index mapping:")
print(zone_to_idx)

n_zones = len(zones)
print("Number of zones (n_zones):", n_zones)

n_aps = X_train.shape[1]
print("Number of APs (n_aps):", n_aps)

n_samples = X_train.shape[0]
print("Number of training samples (n_samples):", n_samples)

# Parameters
learning_rate = 0.1
print("Learning rate:", learning_rate)

n_iterations = 50
print("Number of iterations:", n_iterations)

samples_per_zone_for_init = 2  # Using 2 samples for initialization (adjustable)
print("Samples per zone for initialization:", samples_per_zone_for_init)

# Initialize weights
weights = np.zeros((n_aps, n_zones))
print("\nInitial Weights (before initialization):")
print(weights.T)

for zone in zones:
    zone_idx = zone_to_idx[zone]
    print(f"\nInitializing weights for zone {zone} (index {zone_idx}):")
    zone_samples = X_train[y_train == zone]
    print(f"Samples for zone {zone}:")
    print(zone_samples)

    init_samples = zone_samples[:min(samples_per_zone_for_init, len(zone_samples))]
    print(f"Initial samples (up to {samples_per_zone_for_init}):")
    print(init_samples)

    weights[:, zone_idx] = np.mean(init_samples, axis=0)
    print(f"Updated weights for zone {zone} (mean of initial samples):")
    print(weights[:, zone_idx])

print("\nInitial Weights (after initialization):")
print(weights.T)

# Training
print("\nStarting training...")
for iteration in range(n_iterations):
    print(f"\nIteration {iteration + 1}:")
    print("Weights at start of iteration:")
    print(weights.T)

    for i in range(n_samples):
        input_vector = X_train[i]
        print(f"\n  Sample {i + 1}:")
        print(f"  Input vector: {input_vector}")

        val_j = np.dot(weights.T, input_vector)
        print(f"  VAL_j (dot products for each zone): {val_j}")

        winner_idx = np.argmax(val_j)
        print(f"  Winner index: {winner_idx} (Zone {zones[winner_idx]})")

        old_weights = weights[:, winner_idx].copy()
        weights[:, winner_idx] += learning_rate * (input_vector - weights[:, winner_idx])
        print(f"  Old weights for winner (Zone {zones[winner_idx]}): {old_weights}")
        print(f"  New weights for winner (Zone {zones[winner_idx]}): {weights[:, winner_idx]}")
        print(f"  Updated weights after sample {i + 1}:")
        print(weights.T)

print("\nFinal Trained Weights:")
print(weights.T)

# Testing
print("\nStarting testing...")
correct_predictions = 0
predictions = []

for i in range(len(X_test)):
    input_vector = X_test[i]
    true_zone = y_test[i]
    print(f"\nTest Sample {i + 1}:")
    print(f"  Input vector: {input_vector}")
    print(f"  True zone: {true_zone}")

    val_j = np.dot(weights.T, input_vector)
    print(f"  VAL_j (dot products for each zone): {val_j}")

    predicted_idx = np.argmax(val_j)
    predicted_zone = zones[predicted_idx]
    print(f"  Predicted index: {predicted_idx}")
    print(f"  Predicted zone: {predicted_zone}")

    predictions.append(predicted_zone)
    if predicted_zone == true_zone:
        correct_predictions += 1
        print(f"  Correct: True")
    else:
        print(f"  Correct: False")

# Calculate accuracy
accuracy = correct_predictions / len(X_test) * 100
print(f"\nAccuracy: {accuracy:.2f}% ({correct_predictions}/{len(X_test)} correct)")

# Results
results_df = pd.DataFrame({'True Zone': y_test, 'Predicted Zone': predictions})
print("\nResults:")
print(results_df)
# Out:
# Loading training data:
# Training DataFrame:
#    StudentID  room  CSE-306  CSE-304  CSE-401  CSE-104
# 0    2005037   203     -100      -71     -100      -83
# 1    2005026   203      -94      -58      -87      -80
# 2    2005006   203     -100      -68     -100      -74
# 3    2005074   204     -100      -61     -100      -82
# 4    2005084   204      -94      -58      -87      -80
# 5    2005085   204     -100      -68     -100      -74
#
# Loading test data:
# Test DataFrame:
#    StudentID  room  CSE-306  CSE-304  CSE-401  CSE-104
# 0    2005004   203     -100      -52     -100      -79
# 1    2005014   203      -77      -60      -87      -64
# 2    2005045   203      -72      -67      -77      -70
# 3    2005038   204      -72      -67      -77      -70
# 4    2005108   204      -88      -54      -82      -73
# 5    2005102   204      -72      -60      -81      -63
#
# Extracting training features (X_train) and labels (y_train):
# X_train (RSSI values):
# [[-100  -71 -100  -83]
#  [ -94  -58  -87  -80]
#  [-100  -68 -100  -74]
#  [-100  -61 -100  -82]
#  [ -94  -58  -87  -80]
#  [-100  -68 -100  -74]]
# y_train (room labels):
# ['203' '203' '203' '204' '204' '204']
#
# Extracting test features (X_test) and labels (y_test):
# X_test (RSSI values):
# [[-100  -52 -100  -79]
#  [ -77  -60  -87  -64]
#  [ -72  -67  -77  -70]
#  [ -72  -67  -77  -70]
#  [ -88  -54  -82  -73]
#  [ -72  -60  -81  -63]]
# y_test (room labels):
# ['203' '203' '203' '204' '204' '204']
#
# Defined zones:
# ['203', '204']
# Zone to index mapping:
# {'203': 0, '204': 1}
# Number of zones (n_zones): 2
# Number of APs (n_aps): 4
# Number of training samples (n_samples): 6
# Learning rate: 0.1
# Number of iterations: 50
# Samples per zone for initialization: 2
#
# Initial Weights (before initialization):
# [[0. 0. 0. 0.]
#  [0. 0. 0. 0.]]
#
# Initializing weights for zone 203 (index 0):
# Samples for zone 203:
# [[-100  -71 -100  -83]
#  [ -94  -58  -87  -80]
#  [-100  -68 -100  -74]]
# Initial samples (up to 2):
# [[-100  -71 -100  -83]
#  [ -94  -58  -87  -80]]
# Updated weights for zone 203 (mean of initial samples):
# [-97.  -64.5 -93.5 -81.5]
#
# Initializing weights for zone 204 (index 1):
# Samples for zone 204:
# [[-100  -61 -100  -82]
#  [ -94  -58  -87  -80]
#  [-100  -68 -100  -74]]
# Initial samples (up to 2):
# [[-100  -61 -100  -82]
#  [ -94  -58  -87  -80]]
# Updated weights for zone 204 (mean of initial samples):
# [-97.  -59.5 -93.5 -81. ]
#
# Initial Weights (after initialization):
# [[-97.  -64.5 -93.5 -81.5]
#  [-97.  -59.5 -93.5 -81. ]]
#
# Starting training...
#
# Iteration 1:
# Weights at start of iteration:
# [[-97.  -64.5 -93.5 -81.5]
#  [-97.  -59.5 -93.5 -81. ]]
#
#   Sample 1:
#   Input vector: [-100  -71 -100  -83]
#   VAL_j (dot products for each zone): [30394.  29997.5]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.  -64.5 -93.5 -81.5]
#   New weights for winner (Zone 203): [-97.3  -65.15 -94.15 -81.65]
#   Updated weights after sample 1:
# [[-97.3  -65.15 -94.15 -81.65]
#  [-97.   -59.5  -93.5  -81.  ]]
#
#   Sample 2:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27647.95 27183.5 ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.3  -65.15 -94.15 -81.65]
#   New weights for winner (Zone 203): [-96.97  -64.435 -93.435 -81.485]
#   Updated weights after sample 2:
# [[-96.97  -64.435 -93.435 -81.485]
#  [-97.    -59.5   -93.5   -81.   ]]
#
#   Sample 3:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29451.97 29090.  ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-96.97  -64.435 -93.435 -81.485]
#   New weights for winner (Zone 203): [-97.273  -64.7915 -94.0915 -80.7365]
#   Updated weights after sample 3:
# [[-97.273  -64.7915 -94.0915 -80.7365]
#  [-97.     -59.5    -93.5    -81.    ]]
#
#   Sample 4:
#   Input vector: [-100  -61 -100  -82]
#   VAL_j (dot products for each zone): [29709.1245 29321.5   ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.273  -64.7915 -94.0915 -80.7365]
#   New weights for winner (Zone 203): [-97.5457  -64.41235 -94.68235 -80.86285]
#   Updated weights after sample 4:
# [[-97.5457  -64.41235 -94.68235 -80.86285]
#  [-97.      -59.5     -93.5     -81.     ]]
#
#   Sample 5:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27611.60455 27183.5    ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.5457  -64.41235 -94.68235 -80.86285]
#   New weights for winner (Zone 203): [-97.19113  -63.771115 -93.914115 -80.776565]
#   Updated weights after sample 5:
# [[-97.19113  -63.771115 -93.914115 -80.776565]
#  [-97.       -59.5      -93.5      -81.      ]]
#
#   Sample 6:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29424.42613 29090.     ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.19113  -63.771115 -93.914115 -80.776565]
#   New weights for winner (Zone 203): [-97.472017  -64.1940035 -94.5227035 -80.0989085]
#   Updated weights after sample 6:
# [[-97.472017  -64.1940035 -94.5227035 -80.0989085]
#  [-97.        -59.5       -93.5       -81.       ]]
#
# Iteration 2:
# Weights at start of iteration:
# [[-97.472017  -64.1940035 -94.5227035 -80.0989085]
#  [-97.        -59.5       -93.5       -81.       ]]
#
#   Sample 1:
#   Input vector: [-100  -71 -100  -83]
#   VAL_j (dot products for each zone): [30405.455704 29997.5     ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.472017  -64.1940035 -94.5227035 -80.0989085]
#   New weights for winner (Zone 203): [-97.7248153  -64.87460315 -95.07043315 -80.38901765]
#   Updated weights after sample 1:
# [[-97.7248153  -64.87460315 -95.07043315 -80.38901765]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 2:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27651.10871695 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.7248153  -64.87460315 -95.07043315 -80.38901765]
#   New weights for winner (Zone 203): [-97.35233377 -64.18714284 -94.26338983 -80.35011588]
#   Updated weights after sample 2:
# [[-97.35233377 -64.18714284 -94.26338983 -80.35011588]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 3:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29472.20664877 29090.        ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.35233377 -64.18714284 -94.26338983 -80.35011588]
#   New weights for winner (Zone 203): [-97.61710039 -64.56842855 -94.83705085 -79.7151043 ]
#   Updated weights after sample 3:
# [[-97.61710039 -64.56842855 -94.83705085 -79.7151043 ]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 4:
#   Input vector: [-100  -61 -100  -82]
#   VAL_j (dot products for each zone): [29720.7278184 29321.5      ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.61710039 -64.56842855 -94.83705085 -79.7151043 ]
#   New weights for winner (Zone 203): [-97.85539035 -64.2115857  -95.35334577 -79.94359387]
#   Updated weights after sample 4:
# [[-97.85539035 -64.2115857  -95.35334577 -79.94359387]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 5:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27613.90725466 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.85539035 -64.2115857  -95.35334577 -79.94359387]
#   New weights for winner (Zone 203): [-97.46985132 -63.59042713 -94.51801119 -79.94923448]
#   Updated weights after sample 5:
# [[-97.46985132 -63.59042713 -94.51801119 -79.94923448]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 6:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29439.17864695 29090.        ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.46985132 -63.59042713 -94.51801119 -79.94923448]
#   New weights for winner (Zone 203): [-97.72286619 -64.03138441 -95.06621007 -79.35431103]
#   Updated weights after sample 6:
# [[-97.72286619 -64.03138441 -95.06621007 -79.35431103]
#  [-97.         -59.5        -93.5        -81.        ]]
#
# Iteration 3:
# Weights at start of iteration:
# [[-97.72286619 -64.03138441 -95.06621007 -79.35431103]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 1:
#   Input vector: [-100  -71 -100  -83]
#   VAL_j (dot products for each zone): [30411.54373479 29997.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.72286619 -64.03138441 -95.06621007 -79.35431103]
#   New weights for winner (Zone 203): [-97.95057957 -64.72824597 -95.55958906 -79.71887993]
#   Updated weights after sample 1:
# [[-97.95057957 -64.72824597 -95.55958906 -79.71887993]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 2:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27652.78738864 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.95057957 -64.72824597 -95.55958906 -79.71887993]
#   New weights for winner (Zone 203): [-97.55552161 -64.05542138 -94.70363016 -79.74699194]
#   Updated weights after sample 2:
# [[-97.55552161 -64.05542138 -94.70363016 -79.74699194]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 3:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29482.96123363 29090.        ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.55552161 -64.05542138 -94.70363016 -79.74699194]
#   New weights for winner (Zone 203): [-97.79996945 -64.44987924 -95.23326714 -79.17229274]
#   Updated weights after sample 3:
# [[-97.79996945 -64.44987924 -95.23326714 -79.17229274]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 4:
#   Input vector: [-100  -61 -100  -82]
#   VAL_j (dot products for each zone): [29726.89429754 29321.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.79996945 -64.44987924 -95.23326714 -79.17229274]
#   New weights for winner (Zone 203): [-98.0199725  -64.10489131 -95.70994043 -79.45506347]
#   Updated weights after sample 4:
# [[-98.0199725  -64.10489131 -95.70994043 -79.45506347]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 5:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27615.13100632 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.0199725  -64.10489131 -95.70994043 -79.45506347]
#   New weights for winner (Zone 203): [-97.61797525 -63.49440218 -94.83894638 -79.50955712]
#   Updated weights after sample 5:
# [[-97.61797525 -63.49440218 -94.83894638 -79.50955712]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 6:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29447.01873932 29090.        ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.61797525 -63.49440218 -94.83894638 -79.50955712]
#   New weights for winner (Zone 203): [-97.85617773 -63.94496196 -95.35505175 -78.95860141]
#   Updated weights after sample 6:
# [[-97.85617773 -63.94496196 -95.35505175 -78.95860141]
#  [-97.         -59.5        -93.5        -81.        ]]
#
# Iteration 4:
# Weights at start of iteration:
# [[-97.85617773 -63.94496196 -95.35505175 -78.95860141]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 1:
#   Input vector: [-100  -71 -100  -83]
#   VAL_j (dot products for each zone): [30414.77916396 29997.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.85617773 -63.94496196 -95.35505175 -78.95860141]
#   New weights for winner (Zone 203): [-98.07055996 -64.65046577 -95.81954657 -79.36274127]
#   Updated weights after sample 1:
# [[-98.07055996 -64.65046577 -95.81954657 -79.36274127]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 2:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27653.67950361 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.07055996 -64.65046577 -95.81954657 -79.36274127]
#   New weights for winner (Zone 203): [-97.66350396 -63.98541919 -94.93759191 -79.42646714]
#   Updated weights after sample 2:
# [[-97.66350396 -63.98541919 -94.93759191 -79.42646714]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 3:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29488.67666096 29090.        ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.66350396 -63.98541919 -94.93759191 -79.42646714]
#   New weights for winner (Zone 203): [-97.89715356 -64.38687727 -95.44383272 -78.88382043]
#   Updated weights after sample 3:
# [[-97.89715356 -64.38687727 -95.44383272 -78.88382043]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 4:
#   Input vector: [-100  -61 -100  -82]
#   VAL_j (dot products for each zone): [29730.17141738 29321.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.89715356 -64.38687727 -95.44383272 -78.88382043]
#   New weights for winner (Zone 203): [-98.10743821 -64.04818954 -95.89944945 -79.19543838]
#   Updated weights after sample 4:
# [[-98.10743821 -64.04818954 -95.89944945 -79.19543838]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 5:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27615.78135813 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.10743821 -64.04818954 -95.89944945 -79.19543838]
#   New weights for winner (Zone 203): [-97.69669439 -63.44337059 -95.00950451 -79.27589455]
#   Updated weights after sample 5:
# [[-97.69669439 -63.44337059 -95.00950451 -79.27589455]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 6:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29451.18528584 29090.        ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.69669439 -63.44337059 -95.00950451 -79.27589455]
#   New weights for winner (Zone 203): [-97.92702495 -63.89903353 -95.50855406 -78.74830509]
#   Updated weights after sample 6:
# [[-97.92702495 -63.89903353 -95.50855406 -78.74830509]
#  [-97.         -59.5        -93.5        -81.        ]]
#
# Iteration 5:
# Weights at start of iteration:
# [[-97.92702495 -63.89903353 -95.50855406 -78.74830509]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 1:
#   Input vector: [-100  -71 -100  -83]
#   VAL_j (dot products for each zone): [30416.49860367 29997.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.92702495 -63.89903353 -95.50855406 -78.74830509]
#   New weights for winner (Zone 203): [-98.13432245 -64.60913018 -95.95769865 -79.17347458]
#   Updated weights after sample 1:
# [[-98.13432245 -64.60913018 -95.95769865 -79.17347458]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 2:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27654.15361008 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.13432245 -64.60913018 -95.95769865 -79.17347458]
#   New weights for winner (Zone 203): [-97.72089021 -63.94821716 -95.06192878 -79.25612712]
#   Updated weights after sample 2:
# [[-97.72089021 -63.94821716 -95.06192878 -79.25612712]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 3:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29491.71407338 29090.        ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.72089021 -63.94821716 -95.06192878 -79.25612712]
#   New weights for winner (Zone 203): [-97.94880119 -64.35339544 -95.55573591 -78.73051441]
#   Updated weights after sample 3:
# [[-97.94880119 -64.35339544 -95.55573591 -78.73051441]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 4:
#   Input vector: [-100  -61 -100  -82]
#   VAL_j (dot products for each zone): [29731.91301322 29321.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.94880119 -64.35339544 -95.55573591 -78.73051441]
#   New weights for winner (Zone 203): [-98.15392107 -64.0180559  -96.00016232 -79.05746297]
#   Updated weights after sample 4:
# [[-98.15392107 -64.0180559  -96.00016232 -79.05746297]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 5:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27616.12698175 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.15392107 -64.0180559  -96.00016232 -79.05746297]
#   New weights for winner (Zone 203): [-97.73852896 -63.41625031 -95.10014608 -79.15171667]
#   Updated weights after sample 5:
# [[-97.73852896 -63.41625031 -95.10014608 -79.15171667]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 6:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29453.39955949 29090.        ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.73852896 -63.41625031 -95.10014608 -79.15171667]
#   New weights for winner (Zone 203): [-97.96467607 -63.87462528 -95.59013148 -78.63654501]
#   Updated weights after sample 6:
# [[-97.96467607 -63.87462528 -95.59013148 -78.63654501]
#  [-97.         -59.5        -93.5        -81.        ]]
#
# Iteration 6:
# Weights at start of iteration:
# [[-97.96467607 -63.87462528 -95.59013148 -78.63654501]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 1:
#   Input vector: [-100  -71 -100  -83]
#   VAL_j (dot products for each zone): [30417.41238444 29997.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.96467607 -63.87462528 -95.59013148 -78.63654501]
#   New weights for winner (Zone 203): [-98.16820846 -64.58716275 -96.03111833 -79.07289051]
#   Updated weights after sample 1:
# [[-98.16820846 -64.58716275 -96.03111833 -79.07289051]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 2:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27654.40556969 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.16820846 -64.58716275 -96.03111833 -79.07289051]
#   New weights for winner (Zone 203): [-97.75138761 -63.92844648 -95.1280065  -79.16560145]
#   Updated weights after sample 2:
# [[-97.75138761 -63.92844648 -95.1280065  -79.16560145]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 3:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29493.32827887 29090.        ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.75138761 -63.92844648 -95.1280065  -79.16560145]
#   New weights for winner (Zone 203): [-97.97624885 -64.33560183 -95.61520585 -78.64904131]
#   Updated weights after sample 3:
# [[-97.97624885 -64.33560183 -95.61520585 -78.64904131]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 4:
#   Input vector: [-100  -61 -100  -82]
#   VAL_j (dot products for each zone): [29732.83856866 29321.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.97624885 -64.33560183 -95.61520585 -78.64904131]
#   New weights for winner (Zone 203): [-98.17862397 -64.00204165 -96.05368526 -78.98413718]
#   Updated weights after sample 4:
# [[-98.17862397 -64.00204165 -96.05368526 -78.98413718]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 5:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27616.31066031 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.17862397 -64.00204165 -96.05368526 -78.98413718]
#   New weights for winner (Zone 203): [-97.76076157 -63.40183748 -95.14831674 -79.08572346]
#   Updated weights after sample 5:
# [[-97.76076157 -63.40183748 -95.14831674 -79.08572346]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 6:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29454.5763153 29090.       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.76076157 -63.40183748 -95.14831674 -79.08572346]
#   New weights for winner (Zone 203): [-97.98468541 -63.86165373 -95.63348506 -78.57715111]
#   Updated weights after sample 6:
# [[-97.98468541 -63.86165373 -95.63348506 -78.57715111]
#  [-97.         -59.5        -93.5        -81.        ]]
#
# Iteration 7:
# Weights at start of iteration:
# [[-97.98468541 -63.86165373 -95.63348506 -78.57715111]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 1:
#   Input vector: [-100  -71 -100  -83]
#   VAL_j (dot products for each zone): [30417.898005 29997.5     ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.98468541 -63.86165373 -95.63348506 -78.57715111]
#   New weights for winner (Zone 203): [-98.18621687 -64.57548836 -96.07013656 -79.019436  ]
#   Updated weights after sample 1:
# [[-98.18621687 -64.57548836 -96.07013656 -79.019436  ]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 2:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27654.53947136 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.18621687 -64.57548836 -96.07013656 -79.019436  ]
#   New weights for winner (Zone 203): [-97.76759518 -63.91793952 -95.1631229  -79.1174924 ]
#   Updated weights after sample 2:
# [[-97.76759518 -63.91793952 -95.1631229  -79.1174924 ]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 3:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29494.18613385 29090.        ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.76759518 -63.91793952 -95.1631229  -79.1174924 ]
#   New weights for winner (Zone 203): [-97.99083567 -64.32614557 -95.64681061 -78.60574316]
#   Updated weights after sample 3:
# [[-97.99083567 -64.32614557 -95.64681061 -78.60574316]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 4:
#   Input vector: [-100  -61 -100  -82]
#   VAL_j (dot products for each zone): [29733.33044677 29321.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.99083567 -64.32614557 -95.64681061 -78.60574316]
#   New weights for winner (Zone 203): [-98.1917521  -63.99353101 -96.08212955 -78.94516885]
#   Updated weights after sample 4:
# [[-98.1917521  -63.99353101 -96.08212955 -78.94516885]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 5:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27616.40827462 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.1917521  -63.99353101 -96.08212955 -78.94516885]
#   New weights for winner (Zone 203): [-97.77257689 -63.39417791 -95.17391659 -79.05065196]
#   Updated weights after sample 5:
# [[-97.77257689 -63.39417791 -95.17391659 -79.05065196]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 6:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29455.20169158 29090.        ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.77257689 -63.39417791 -95.17391659 -79.05065196]
#   New weights for winner (Zone 203): [-97.9953192  -63.85476012 -95.65652493 -78.54558677]
#   Updated weights after sample 6:
# [[-97.9953192  -63.85476012 -95.65652493 -78.54558677]
#  [-97.         -59.5        -93.5        -81.        ]]
#
# Iteration 8:
# Weights at start of iteration:
# [[-97.9953192  -63.85476012 -95.65652493 -78.54558677]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 1:
#   Input vector: [-100  -71 -100  -83]
#   VAL_j (dot products for each zone): [30418.15608367 29997.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.9953192  -63.85476012 -95.65652493 -78.54558677]
#   New weights for winner (Zone 203): [-98.19578728 -64.56928411 -96.09087244 -78.99102809]
#   Updated weights after sample 1:
# [[-98.19578728 -64.56928411 -96.09087244 -78.99102809]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 2:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27654.6106322 27183.5      ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.19578728 -64.56928411 -96.09087244 -78.99102809]
#   New weights for winner (Zone 203): [-97.77620855 -63.9123557  -95.1817852  -79.09192528]
#   Updated weights after sample 2:
# [[-97.77620855 -63.9123557  -95.1817852  -79.09192528]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 3:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29494.64203316 29090.        ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.77620855 -63.9123557  -95.1817852  -79.09192528]
#   New weights for winner (Zone 203): [-97.9985877  -64.32112013 -95.66360668 -78.58273275]
#   Updated weights after sample 3:
# [[-97.9985877  -64.32112013 -95.66360668 -78.58273275]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 4:
#   Input vector: [-100  -61 -100  -82]
#   VAL_j (dot products for each zone): [29733.59185096 29321.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.9985877  -64.32112013 -95.66360668 -78.58273275]
#   New weights for winner (Zone 203): [-98.19872893 -63.98900812 -96.09724601 -78.92445948]
#   Updated weights after sample 4:
# [[-98.19872893 -63.98900812 -96.09724601 -78.92445948]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 5:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27616.46015087 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.19872893 -63.98900812 -96.09724601 -78.92445948]
#   New weights for winner (Zone 203): [-97.77885603 -63.3901073  -95.18752141 -79.03201353]
#   Updated weights after sample 5:
# [[-97.77885603 -63.3901073  -95.18752141 -79.03201353]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 6:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29455.53404217 29090.        ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.77885603 -63.3901073  -95.18752141 -79.03201353]
#   New weights for winner (Zone 203): [-98.00097043 -63.85109657 -95.66876927 -78.52881218]
#   Updated weights after sample 6:
# [[-98.00097043 -63.85109657 -95.66876927 -78.52881218]
#  [-97.         -59.5        -93.5        -81.        ]]
#
# Iteration 9:
# Weights at start of iteration:
# [[-98.00097043 -63.85109657 -95.66876927 -78.52881218]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 1:
#   Input vector: [-100  -71 -100  -83]
#   VAL_j (dot products for each zone): [30418.29323726 29997.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.00097043 -63.85109657 -95.66876927 -78.52881218]
#   New weights for winner (Zone 203): [-98.20087339 -64.56598692 -96.10189234 -78.97593096]
#   Updated weights after sample 1:
# [[-98.20087339 -64.56598692 -96.10189234 -78.97593096]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 2:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27654.64844999 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.20087339 -64.56598692 -96.10189234 -78.97593096]
#   New weights for winner (Zone 203): [-97.78078605 -63.90938822 -95.19170311 -79.07833786]
#   Updated weights after sample 2:
# [[-97.78078605 -63.90938822 -95.19170311 -79.07833786]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 3:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29494.88431674 29090.        ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.78078605 -63.90938822 -95.19170311 -79.07833786]
#   New weights for winner (Zone 203): [-98.00270744 -64.3184494  -95.6725328  -78.57050408]
#   Updated weights after sample 3:
# [[-98.00270744 -64.3184494  -95.6725328  -78.57050408]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 4:
#   Input vector: [-100  -61 -100  -82]
#   VAL_j (dot products for each zone): [29733.73077187 29321.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.00270744 -64.3184494  -95.6725328  -78.57050408]
#   New weights for winner (Zone 203): [-98.2024367  -63.98660446 -96.10527952 -78.91345367]
#   Updated weights after sample 4:
# [[-98.2024367  -63.98660446 -96.10527952 -78.91345367]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 5:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27616.48772004 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.2024367  -63.98660446 -96.10527952 -78.91345367]
#   New weights for winner (Zone 203): [-97.78219303 -63.38794402 -95.19475156 -79.0221083 ]
#   Updated weights after sample 5:
# [[-97.78219303 -63.38794402 -95.19475156 -79.0221083 ]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 6:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29455.71066691 29090.        ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.78219303 -63.38794402 -95.19475156 -79.0221083 ]
#   New weights for winner (Zone 203): [-98.00397373 -63.84914961 -95.67527641 -78.51989747]
#   Updated weights after sample 6:
# [[-98.00397373 -63.84914961 -95.67527641 -78.51989747]
#  [-97.         -59.5        -93.5        -81.        ]]
#
# Iteration 10:
# Weights at start of iteration:
# [[-98.00397373 -63.84914961 -95.67527641 -78.51989747]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 1:
#   Input vector: [-100  -71 -100  -83]
#   VAL_j (dot products for each zone): [30418.3661263 29997.5      ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.00397373 -63.84914961 -95.67527641 -78.51989747]
#   New weights for winner (Zone 203): [-98.20357635 -64.56423465 -96.10774877 -78.96790772]
#   Updated weights after sample 1:
# [[-98.20357635 -64.56423465 -96.10774877 -78.96790772]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 2:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27654.66854791 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.20357635 -64.56423465 -96.10774877 -78.96790772]
#   New weights for winner (Zone 203): [-97.78321872 -63.90781119 -95.19697389 -79.07111695]
#   Updated weights after sample 2:
# [[-97.78321872 -63.90781119 -95.19697389 -79.07111695]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 3:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29495.01307618 29090.        ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.78321872 -63.90781119 -95.19697389 -79.07111695]
#   New weights for winner (Zone 203): [-98.00489685 -64.31703007 -95.6772765  -78.56400526]
#   Updated weights after sample 3:
# [[-98.00489685 -64.31703007 -95.6772765  -78.56400526]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 4:
#   Input vector: [-100  -61 -100  -82]
#   VAL_j (dot products for each zone): [29733.80460013 29321.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.00489685 -64.31703007 -95.6772765  -78.56400526]
#   New weights for winner (Zone 203): [-98.20440716 -63.98532706 -96.10954885 -78.90760473]
#   Updated weights after sample 4:
# [[-98.20440716 -63.98532706 -96.10954885 -78.90760473]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 5:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27616.50237143 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.20440716 -63.98532706 -96.10954885 -78.90760473]
#   New weights for winner (Zone 203): [-97.78396645 -63.38679436 -95.19859397 -79.01684426]
#   Updated weights after sample 5:
# [[-97.78396645 -63.38679436 -95.19859397 -79.01684426]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 6:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29455.80453253 29090.        ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.78396645 -63.38679436 -95.19859397 -79.01684426]
#   New weights for winner (Zone 203): [-98.0055698  -63.84811492 -95.67873457 -78.51515983]
#   Updated weights after sample 6:
# [[-98.0055698  -63.84811492 -95.67873457 -78.51515983]
#  [-97.         -59.5        -93.5        -81.        ]]
#
# Iteration 11:
# Weights at start of iteration:
# [[-98.0055698  -63.84811492 -95.67873457 -78.51515983]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 1:
#   Input vector: [-100  -71 -100  -83]
#   VAL_j (dot products for each zone): [30418.40486253 29997.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.0055698  -63.84811492 -95.67873457 -78.51515983]
#   New weights for winner (Zone 203): [-98.20501282 -64.56330343 -96.11086111 -78.96364385]
#   Updated weights after sample 1:
# [[-98.20501282 -64.56330343 -96.11086111 -78.96364385]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 2:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27654.67922877 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.20501282 -64.56330343 -96.11086111 -78.96364385]
#   New weights for winner (Zone 203): [-97.78451154 -63.90697309 -95.199775   -79.06727946]
#   Updated weights after sample 2:
# [[-97.78451154 -63.90697309 -95.199775   -79.06727946]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 3:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29495.08150422 29090.        ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.78451154 -63.90697309 -95.199775   -79.06727946]
#   New weights for winner (Zone 203): [-98.00606039 -64.31627578 -95.6797975  -78.56055152]
#   Updated weights after sample 3:
# [[-98.00606039 -64.31627578 -95.6797975  -78.56055152]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 4:
#   Input vector: [-100  -61 -100  -82]
#   VAL_j (dot products for each zone): [29733.8438355 29321.5      ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.00606039 -64.31627578 -95.6797975  -78.56055152]
#   New weights for winner (Zone 203): [-98.20545435 -63.9846482  -96.11181775 -78.90449637]
#   Updated weights after sample 4:
# [[-98.20545435 -63.9846482  -96.11181775 -78.90449637]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 5:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27616.51015777 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.20545435 -63.9846482  -96.11181775 -78.90449637]
#   New weights for winner (Zone 203): [-97.78490891 -63.38618338 -95.20063598 -79.01404673]
#   Updated weights after sample 5:
# [[-97.78490891 -63.38618338 -95.20063598 -79.01404673]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 6:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29455.85441657 29090.        ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.78490891 -63.38618338 -95.20063598 -79.01404673]
#   New weights for winner (Zone 203): [-98.00641802 -63.84756504 -95.68057238 -78.51264206]
#   Updated weights after sample 6:
# [[-98.00641802 -63.84756504 -95.68057238 -78.51264206]
#  [-97.         -59.5        -93.5        -81.        ]]
#
# Iteration 12:
# Weights at start of iteration:
# [[-98.00641802 -63.84756504 -95.68057238 -78.51264206]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 1:
#   Input vector: [-100  -71 -100  -83]
#   VAL_j (dot products for each zone): [30418.42544855 29997.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.00641802 -63.84756504 -95.68057238 -78.51264206]
#   New weights for winner (Zone 203): [-98.20577622 -64.56280854 -96.11251514 -78.96137785]
#   Updated weights after sample 1:
# [[-98.20577622 -64.56280854 -96.11251514 -78.96137785]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 2:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27654.68490502 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.20577622 -64.56280854 -96.11251514 -78.96137785]
#   New weights for winner (Zone 203): [-97.7851986  -63.90652768 -95.20126363 -79.06524007]
#   Updated weights after sample 2:
# [[-97.7851986  -63.90652768 -95.20126363 -79.06524007]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 3:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29495.11786968 29090.        ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.7851986  -63.90652768 -95.20126363 -79.06524007]
#   New weights for winner (Zone 203): [-98.00667874 -64.31587492 -95.68113726 -78.55871606]
#   Updated weights after sample 3:
# [[-98.00667874 -64.31587492 -95.68113726 -78.55871606]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 4:
#   Input vector: [-100  -61 -100  -82]
#   VAL_j (dot products for each zone): [29733.86468678 29321.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.00667874 -64.31587492 -95.68113726 -78.55871606]
#   New weights for winner (Zone 203): [-98.20601086 -63.98428742 -96.11302354 -78.90284445]
#   Updated weights after sample 4:
# [[-98.20601086 -63.98428742 -96.11302354 -78.90284445]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 5:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27616.51429576 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.20601086 -63.98428742 -96.11302354 -78.90284445]
#   New weights for winner (Zone 203): [-97.78540978 -63.38585868 -95.20172118 -79.01256001]
#   Updated weights after sample 5:
# [[-97.78540978 -63.38585868 -95.20172118 -79.01256001]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 6:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29455.880927 29090.      ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.78540978 -63.38585868 -95.20172118 -79.01256001]
#   New weights for winner (Zone 203): [-98.0068688  -63.84727281 -95.68154907 -78.51130401]
#   Updated weights after sample 6:
# [[-98.0068688  -63.84727281 -95.68154907 -78.51130401]
#  [-97.         -59.5        -93.5        -81.        ]]
#
# Iteration 13:
# Weights at start of iteration:
# [[-98.0068688  -63.84727281 -95.68154907 -78.51130401]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 1:
#   Input vector: [-100  -71 -100  -83]
#   VAL_j (dot products for each zone): [30418.4363888 29997.5      ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.0068688  -63.84727281 -95.68154907 -78.51130401]
#   New weights for winner (Zone 203): [-98.20618192 -64.56254553 -96.11339416 -78.96017361]
#   Updated weights after sample 1:
# [[-98.20618192 -64.56254553 -96.11339416 -78.96017361]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 2:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27654.68792161 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.20618192 -64.56254553 -96.11339416 -78.96017361]
#   New weights for winner (Zone 203): [-97.78556373 -63.90629098 -95.20205474 -79.06415625]
#   Updated weights after sample 2:
# [[-97.78556373 -63.90629098 -95.20205474 -79.06415625]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 3:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29495.13719578 29090.        ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.78556373 -63.90629098 -95.20205474 -79.06415625]
#   New weights for winner (Zone 203): [-98.00700735 -64.31566188 -95.68184927 -78.55774062]
#   Updated weights after sample 3:
# [[-98.00700735 -64.31566188 -95.68184927 -78.55774062]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 4:
#   Input vector: [-100  -61 -100  -82]
#   VAL_j (dot products for each zone): [29733.87576801 29321.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.00700735 -64.31566188 -95.68184927 -78.55774062]
#   New weights for winner (Zone 203): [-98.20630662 -63.98409569 -96.11366434 -78.90196656]
#   Updated weights after sample 4:
# [[-98.20630662 -63.98409569 -96.11366434 -78.90196656]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 5:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27616.51649485 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.20630662 -63.98409569 -96.11366434 -78.90196656]
#   New weights for winner (Zone 203): [-97.78567596 -63.38568612 -95.20229791 -79.0117699 ]
#   Updated weights after sample 5:
# [[-97.78567596 -63.38568612 -95.20229791 -79.0117699 ]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 6:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29455.89501572 29090.        ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.78567596 -63.38568612 -95.20229791 -79.0117699 ]
#   New weights for winner (Zone 203): [-98.00710836 -63.84711751 -95.68206812 -78.51059291]
#   Updated weights after sample 6:
# [[-98.00710836 -63.84711751 -95.68206812 -78.51059291]
#  [-97.         -59.5        -93.5        -81.        ]]
#
# Iteration 14:
# Weights at start of iteration:
# [[-98.00710836 -63.84711751 -95.68206812 -78.51059291]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 1:
#   Input vector: [-100  -71 -100  -83]
#   VAL_j (dot products for each zone): [30418.4422029 29997.5      ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.00710836 -63.84711751 -95.68206812 -78.51059291]
#   New weights for winner (Zone 203): [-98.20639753 -64.56240576 -96.11386131 -78.95953362]
#   Updated weights after sample 1:
# [[-98.20639753 -64.56240576 -96.11386131 -78.95953362]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 2:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27654.68952475 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.20639753 -64.56240576 -96.11386131 -78.95953362]
#   New weights for winner (Zone 203): [-97.78575777 -63.90616518 -95.20247517 -79.06358026]
#   Updated weights after sample 2:
# [[-97.78575777 -63.90616518 -95.20247517 -79.06358026]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 3:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29495.14746646 29090.        ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.78575777 -63.90616518 -95.20247517 -79.06358026]
#   New weights for winner (Zone 203): [-98.007182   -64.31554867 -95.68222766 -78.55722223]
#   Updated weights after sample 3:
# [[-98.007182   -64.31554867 -95.68222766 -78.55722223]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 4:
#   Input vector: [-100  -61 -100  -82]
#   VAL_j (dot products for each zone): [29733.88165703 29321.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.007182   -64.31554867 -95.68222766 -78.55722223]
#   New weights for winner (Zone 203): [-98.2064638  -63.9839938  -96.11400489 -78.90150001]
#   Updated weights after sample 4:
# [[-98.2064638  -63.9839938  -96.11400489 -78.90150001]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 5:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27616.51766354 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.2064638  -63.9839938  -96.11400489 -78.90150001]
#   New weights for winner (Zone 203): [-97.78581742 -63.38559442 -95.2026044  -79.01135001]
#   Updated weights after sample 5:
# [[-97.78581742 -63.38559442 -95.2026044  -79.01135001]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 6:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29455.90250305 29090.        ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.78581742 -63.38559442 -95.2026044  -79.01135001]
#   New weights for winner (Zone 203): [-98.00723567 -63.84703498 -95.68234396 -78.51021501]
#   Updated weights after sample 6:
# [[-98.00723567 -63.84703498 -95.68234396 -78.51021501]
#  [-97.         -59.5        -93.5        -81.        ]]
#
# Iteration 15:
# Weights at start of iteration:
# [[-98.00723567 -63.84703498 -95.68234396 -78.51021501]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 1:
#   Input vector: [-100  -71 -100  -83]
#   VAL_j (dot products for each zone): [30418.44529275 29997.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.00723567 -63.84703498 -95.68234396 -78.51021501]
#   New weights for winner (Zone 203): [-98.20651211 -64.56233148 -96.11410957 -78.95919351]
#   Updated weights after sample 1:
# [[-98.20651211 -64.56233148 -96.11410957 -78.95919351]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 2:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27654.69037672 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.20651211 -64.56233148 -96.11410957 -78.95919351]
#   New weights for winner (Zone 203): [-97.7858609  -63.90609833 -95.20269861 -79.06327416]
#   Updated weights after sample 2:
# [[-97.7858609  -63.90609833 -95.20269861 -79.06327416]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 3:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29495.15292472 29090.        ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.7858609  -63.90609833 -95.20269861 -79.06327416]
#   New weights for winner (Zone 203): [-98.00727481 -64.3154885  -95.68242875 -78.55694674]
#   Updated weights after sample 3:
# [[-98.00727481 -64.3154885  -95.68242875 -78.55694674]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 4:
#   Input vector: [-100  -61 -100  -82]
#   VAL_j (dot products for each zone): [29733.88478669 29321.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.00727481 -64.3154885  -95.68242875 -78.55694674]
#   New weights for winner (Zone 203): [-98.20654733 -63.98393965 -96.11418587 -78.90125207]
#   Updated weights after sample 4:
# [[-98.20654733 -63.98393965 -96.11418587 -78.90125207]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 5:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27616.51828463 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.20654733 -63.98393965 -96.11418587 -78.90125207]
#   New weights for winner (Zone 203): [-97.78589259 -63.38554568 -95.20276729 -79.01112686]
#   Updated weights after sample 5:
# [[-97.78589259 -63.38554568 -95.20276729 -79.01112686]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 6:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29455.90648212 29090.        ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.78589259 -63.38554568 -95.20276729 -79.01112686]
#   New weights for winner (Zone 203): [-98.00730333 -63.84699112 -95.68249056 -78.51001417]
#   Updated weights after sample 6:
# [[-98.00730333 -63.84699112 -95.68249056 -78.51001417]
#  [-97.         -59.5        -93.5        -81.        ]]
#
# Iteration 16:
# Weights at start of iteration:
# [[-98.00730333 -63.84699112 -95.68249056 -78.51001417]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 1:
#   Input vector: [-100  -71 -100  -83]
#   VAL_j (dot products for each zone): [30418.44693483 29997.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.00730333 -63.84699112 -95.68249056 -78.51001417]
#   New weights for winner (Zone 203): [-98.206573   -64.562292   -96.1142415  -78.95901276]
#   Updated weights after sample 1:
# [[-98.206573   -64.562292   -96.1142415  -78.95901276]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 2:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27654.69082949 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.206573   -64.562292   -96.1142415  -78.95901276]
# ...
#
#   Sample 2:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27654.69134303 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.20664207 -64.56224723 -96.11439114 -78.95880775]
#   New weights for winner (Zone 203): [-97.78597786 -63.90602251 -95.20295203 -79.06292697]
#   Updated weights after sample 2:
# [[-97.78597786 -63.90602251 -95.20295203 -79.06292697]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 3:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29495.1591155 29090.       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.78597786 -63.90602251 -95.20295203 -79.06292697]
#   New weights for winner (Zone 203): [-98.00738007 -64.31542026 -95.68265683 -78.55663428]
#   Updated weights after sample 3:
# [[-98.00738007 -64.31542026 -95.68265683 -78.55663428]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 4:
#   Input vector: [-100  -61 -100  -82]
#   VAL_j (dot products for each zone): [29733.88833637 29321.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.00738007 -64.31542026 -95.68265683 -78.55663428]
#   New weights for winner (Zone 203): [-98.20664207 -63.98387823 -96.11439114 -78.90097085]
#   Updated weights after sample 4:
# [[-98.20664207 -63.98387823 -96.11439114 -78.90097085]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 5:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27616.51898907 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.20664207 -63.98387823 -96.11439114 -78.90097085]
#   New weights for winner (Zone 203): [-97.78597786 -63.38549041 -95.20295203 -79.01087376]
#   Updated weights after sample 5:
# [[-97.78597786 -63.38549041 -95.20295203 -79.01087376]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 6:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29455.9109952 29090.       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.78597786 -63.38549041 -95.20295203 -79.01087376]
#   New weights for winner (Zone 203): [-98.00738007 -63.84694137 -95.68265683 -78.50978639]
#   Updated weights after sample 6:
# [[-98.00738007 -63.84694137 -95.68265683 -78.50978639]
#  [-97.         -59.5        -93.5        -81.        ]]
#
# Iteration 47:
# Weights at start of iteration:
# [[-98.00738007 -63.84694137 -95.68265683 -78.50978639]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 1:
#   Input vector: [-100  -71 -100  -83]
#   VAL_j (dot products for each zone): [30418.44879727 29997.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.00738007 -63.84694137 -95.68265683 -78.50978639]
#   New weights for winner (Zone 203): [-98.20664207 -64.56224723 -96.11439114 -78.95880775]
#   Updated weights after sample 1:
# [[-98.20664207 -64.56224723 -96.11439114 -78.95880775]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 2:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27654.69134303 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.20664207 -64.56224723 -96.11439114 -78.95880775]
#   New weights for winner (Zone 203): [-97.78597786 -63.90602251 -95.20295203 -79.06292697]
#   Updated weights after sample 2:
# [[-97.78597786 -63.90602251 -95.20295203 -79.06292697]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 3:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29495.1591155 29090.       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.78597786 -63.90602251 -95.20295203 -79.06292697]
#   New weights for winner (Zone 203): [-98.00738007 -64.31542026 -95.68265683 -78.55663428]
#   Updated weights after sample 3:
# [[-98.00738007 -64.31542026 -95.68265683 -78.55663428]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 4:
#   Input vector: [-100  -61 -100  -82]
#   VAL_j (dot products for each zone): [29733.88833637 29321.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.00738007 -64.31542026 -95.68265683 -78.55663428]
#   New weights for winner (Zone 203): [-98.20664207 -63.98387823 -96.11439114 -78.90097085]
#   Updated weights after sample 4:
# [[-98.20664207 -63.98387823 -96.11439114 -78.90097085]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 5:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27616.51898907 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.20664207 -63.98387823 -96.11439114 -78.90097085]
#   New weights for winner (Zone 203): [-97.78597786 -63.38549041 -95.20295203 -79.01087376]
#   Updated weights after sample 5:
# [[-97.78597786 -63.38549041 -95.20295203 -79.01087376]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 6:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29455.9109952 29090.       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.78597786 -63.38549041 -95.20295203 -79.01087376]
#   New weights for winner (Zone 203): [-98.00738007 -63.84694137 -95.68265683 -78.50978639]
#   Updated weights after sample 6:
# [[-98.00738007 -63.84694137 -95.68265683 -78.50978639]
#  [-97.         -59.5        -93.5        -81.        ]]
#
# Iteration 48:
# Weights at start of iteration:
# [[-98.00738007 -63.84694137 -95.68265683 -78.50978639]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 1:
#   Input vector: [-100  -71 -100  -83]
#   VAL_j (dot products for each zone): [30418.44879727 29997.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.00738007 -63.84694137 -95.68265683 -78.50978639]
#   New weights for winner (Zone 203): [-98.20664207 -64.56224723 -96.11439114 -78.95880775]
#   Updated weights after sample 1:
# [[-98.20664207 -64.56224723 -96.11439114 -78.95880775]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 2:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27654.69134303 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.20664207 -64.56224723 -96.11439114 -78.95880775]
#   New weights for winner (Zone 203): [-97.78597786 -63.90602251 -95.20295203 -79.06292697]
#   Updated weights after sample 2:
# [[-97.78597786 -63.90602251 -95.20295203 -79.06292697]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 3:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29495.1591155 29090.       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.78597786 -63.90602251 -95.20295203 -79.06292697]
#   New weights for winner (Zone 203): [-98.00738007 -64.31542026 -95.68265683 -78.55663428]
#   Updated weights after sample 3:
# [[-98.00738007 -64.31542026 -95.68265683 -78.55663428]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 4:
#   Input vector: [-100  -61 -100  -82]
#   VAL_j (dot products for each zone): [29733.88833637 29321.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.00738007 -64.31542026 -95.68265683 -78.55663428]
#   New weights for winner (Zone 203): [-98.20664207 -63.98387823 -96.11439114 -78.90097085]
#   Updated weights after sample 4:
# [[-98.20664207 -63.98387823 -96.11439114 -78.90097085]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 5:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27616.51898907 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.20664207 -63.98387823 -96.11439114 -78.90097085]
#   New weights for winner (Zone 203): [-97.78597786 -63.38549041 -95.20295203 -79.01087376]
#   Updated weights after sample 5:
# [[-97.78597786 -63.38549041 -95.20295203 -79.01087376]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 6:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29455.9109952 29090.       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.78597786 -63.38549041 -95.20295203 -79.01087376]
#   New weights for winner (Zone 203): [-98.00738007 -63.84694137 -95.68265683 -78.50978639]
#   Updated weights after sample 6:
# [[-98.00738007 -63.84694137 -95.68265683 -78.50978639]
#  [-97.         -59.5        -93.5        -81.        ]]
#
# Iteration 49:
# Weights at start of iteration:
# [[-98.00738007 -63.84694137 -95.68265683 -78.50978639]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 1:
#   Input vector: [-100  -71 -100  -83]
#   VAL_j (dot products for each zone): [30418.44879727 29997.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.00738007 -63.84694137 -95.68265683 -78.50978639]
#   New weights for winner (Zone 203): [-98.20664207 -64.56224723 -96.11439114 -78.95880775]
#   Updated weights after sample 1:
# [[-98.20664207 -64.56224723 -96.11439114 -78.95880775]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 2:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27654.69134303 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.20664207 -64.56224723 -96.11439114 -78.95880775]
#   New weights for winner (Zone 203): [-97.78597786 -63.90602251 -95.20295203 -79.06292697]
#   Updated weights after sample 2:
# [[-97.78597786 -63.90602251 -95.20295203 -79.06292697]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 3:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29495.1591155 29090.       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.78597786 -63.90602251 -95.20295203 -79.06292697]
#   New weights for winner (Zone 203): [-98.00738007 -64.31542026 -95.68265683 -78.55663428]
#   Updated weights after sample 3:
# [[-98.00738007 -64.31542026 -95.68265683 -78.55663428]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 4:
#   Input vector: [-100  -61 -100  -82]
#   VAL_j (dot products for each zone): [29733.88833637 29321.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.00738007 -64.31542026 -95.68265683 -78.55663428]
#   New weights for winner (Zone 203): [-98.20664207 -63.98387823 -96.11439114 -78.90097085]
#   Updated weights after sample 4:
# [[-98.20664207 -63.98387823 -96.11439114 -78.90097085]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 5:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27616.51898907 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.20664207 -63.98387823 -96.11439114 -78.90097085]
#   New weights for winner (Zone 203): [-97.78597786 -63.38549041 -95.20295203 -79.01087376]
#   Updated weights after sample 5:
# [[-97.78597786 -63.38549041 -95.20295203 -79.01087376]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 6:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29455.9109952 29090.       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.78597786 -63.38549041 -95.20295203 -79.01087376]
#   New weights for winner (Zone 203): [-98.00738007 -63.84694137 -95.68265683 -78.50978639]
#   Updated weights after sample 6:
# [[-98.00738007 -63.84694137 -95.68265683 -78.50978639]
#  [-97.         -59.5        -93.5        -81.        ]]
#
# Iteration 50:
# Weights at start of iteration:
# [[-98.00738007 -63.84694137 -95.68265683 -78.50978639]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 1:
#   Input vector: [-100  -71 -100  -83]
#   VAL_j (dot products for each zone): [30418.44879727 29997.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.00738007 -63.84694137 -95.68265683 -78.50978639]
#   New weights for winner (Zone 203): [-98.20664207 -64.56224723 -96.11439114 -78.95880775]
#   Updated weights after sample 1:
# [[-98.20664207 -64.56224723 -96.11439114 -78.95880775]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 2:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27654.69134303 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.20664207 -64.56224723 -96.11439114 -78.95880775]
#   New weights for winner (Zone 203): [-97.78597786 -63.90602251 -95.20295203 -79.06292697]
#   Updated weights after sample 2:
# [[-97.78597786 -63.90602251 -95.20295203 -79.06292697]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 3:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29495.1591155 29090.       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.78597786 -63.90602251 -95.20295203 -79.06292697]
#   New weights for winner (Zone 203): [-98.00738007 -64.31542026 -95.68265683 -78.55663428]
#   Updated weights after sample 3:
# [[-98.00738007 -64.31542026 -95.68265683 -78.55663428]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 4:
#   Input vector: [-100  -61 -100  -82]
#   VAL_j (dot products for each zone): [29733.88833637 29321.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.00738007 -64.31542026 -95.68265683 -78.55663428]
#   New weights for winner (Zone 203): [-98.20664207 -63.98387823 -96.11439114 -78.90097085]
#   Updated weights after sample 4:
# [[-98.20664207 -63.98387823 -96.11439114 -78.90097085]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 5:
#   Input vector: [-94 -58 -87 -80]
#   VAL_j (dot products for each zone): [27616.51898907 27183.5       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-98.20664207 -63.98387823 -96.11439114 -78.90097085]
#   New weights for winner (Zone 203): [-97.78597786 -63.38549041 -95.20295203 -79.01087376]
#   Updated weights after sample 5:
# [[-97.78597786 -63.38549041 -95.20295203 -79.01087376]
#  [-97.         -59.5        -93.5        -81.        ]]
#
#   Sample 6:
#   Input vector: [-100  -68 -100  -74]
#   VAL_j (dot products for each zone): [29455.9109952 29090.       ]
#   Winner index: 0 (Zone 203)
#   Old weights for winner (Zone 203): [-97.78597786 -63.38549041 -95.20295203 -79.01087376]
#   New weights for winner (Zone 203): [-98.00738007 -63.84694137 -95.68265683 -78.50978639]
#   Updated weights after sample 6:
# [[-98.00738007 -63.84694137 -95.68265683 -78.50978639]
#  [-97.         -59.5        -93.5        -81.        ]]
#
# Final Trained Weights:
# [[-98.00738007 -63.84694137 -95.68265683 -78.50978639]
#  [-97.         -59.5        -93.5        -81.        ]]
#
# Starting testing...
#
# Test Sample 1:
#   Input vector: [-100  -52 -100  -79]
#   True zone: 203
#   VAL_j (dot products for each zone): [28891.31776575 28543.        ]
#   Predicted index: 0
#   Predicted zone: 203
#   Correct: True
#
# Test Sample 2:
#   Input vector: [-77 -60 -87 -64]
#   True zone: 203
#   VAL_j (dot products for each zone): [24726.40222042 24357.5       ]
#   Predicted index: 0
#   Predicted zone: 203
#   Correct: True
#
# Test Sample 3:
#   Input vector: [-72 -67 -77 -70]
#   True zone: 203
#   VAL_j (dot products for each zone): [24197.52605969 23840.        ]
#   Predicted index: 0
#   Predicted zone: 203
#   Correct: True
#
# Test Sample 4:
#   Input vector: [-72 -67 -77 -70]
#   True zone: 204
#   VAL_j (dot products for each zone): [24197.52605969 23840.        ]
#   Predicted index: 0
#   Predicted zone: 203
#   Correct: False
#
# Test Sample 5:
#   Input vector: [-88 -54 -82 -73]
#   True zone: 204
#   VAL_j (dot products for each zone): [25649.57654639 25329.        ]
#   Predicted index: 0
#   Predicted zone: 203
#   Correct: False
#
# Test Sample 6:
#   Input vector: [-72 -60 -81 -63]
#   True zone: 204
#   VAL_j (dot products for each zone): [23583.75959271 23230.5       ]
#   Predicted index: 0
#   Predicted zone: 203
#   Correct: False
#
# Accuracy: 50.00% (3/6 correct)
#
# Results:
#   True Zone Predicted Zone
# 0       203            203
# 1       203            203
# 2       203            203
# 3       204            203
# 4       204            203
# 5       204            203
